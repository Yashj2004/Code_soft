# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("/content/creditcard (2).csv")
data.head()
# Out:
#    Time    V1    V2    V3    V4    V5    V6    V7    V8    V9  ...       V21       V22   V23  \
# 0     0 -1.36 -0.07  2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ... -1.83e-02  2.78e-01 -0.11
# 1     0  1.19  0.27  0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -2.26e-01 -6.39e-01  0.10
# 2     1 -1.36 -1.34  1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  2.48e-01  7.72e-01  0.91
# 3     1 -0.97 -0.19  1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -1.08e-01  5.27e-03 -0.19
# 4     2 -1.16  0.88  1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ... -9.43e-03  7.98e-01 -0.14
#
#     V24   V25   V26       V27   V28  Amount  Class
# 0  0.07  0.13 -0.19  1.34e-01 -0.02  149.62    0.0
# 1 -0.34  0.17  0.13 -8.98e-03  0.01    2.69    0.0
# 2 -0.69 -0.33 -0.14 -5.54e-02 -0.06  378.66    0.0
# 3 -1.18  0.65 -0.22  6.27e-02  0.06  123.50    0.0
# 4  0.14 -0.21  0.50  2.19e-01  0.22   69.99    0.0
#
# [5 rows x 31 columns]

# %%
pd.set_option('display.width',100)

# %%
data.shape
# Out:
# (63472, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63472 entries, 0 to 63471
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    63472 non-null  int64
#  1   V1      63472 non-null  float64
#  2   V2      63472 non-null  float64
#  3   V3      63472 non-null  float64
#  4   V4      63472 non-null  float64
#  5   V5      63472 non-null  float64
#  6   V6      63472 non-null  float64
#  7   V7      63472 non-null  float64
#  8   V8      63472 non-null  float64
#  9   V9      63472 non-null  float64
#  10  V10     63471 non-null  float64
#  11  V11     63471 non-null  float64
#  12  V12     63471 non-null  float64
#  13  V13     63471 non-null  float64
#  14  V14     63471 non-null  float64
#  15  V15     63471 non-null  float64
#  16  V16     63471 non-null  float64
#  17  V17     63471 non-null  float64
#  18  V18     63471 non-null  float64
#  19  V19     63471 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        1
# V2        1
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
pd.set_option('display.precision',2)

# %%
data.describe()
# Out:
#            Time        V1        V2        V3        V4        V5        V6        V7        V8  \
# count  49610.00  49610.00  49610.00  49610.00  49609.00  49609.00  49609.00  49609.00  49609.00
# mean   28803.56     -0.24      0.01      0.69      0.19     -0.26      0.10     -0.12      0.05
# std    13097.47      1.89      1.63      1.51      1.40      1.41      1.31      1.28      1.22
# min        0.00    -56.41    -72.72    -32.97     -5.17    -42.15    -26.16    -26.55    -41.48
# 25%    21734.25     -0.99     -0.56      0.22     -0.72     -0.87     -0.64     -0.61     -0.15
# 50%    33390.00     -0.25      0.08      0.80      0.19     -0.29     -0.15     -0.08      0.06
# 75%    38852.75      1.16      0.73      1.43      1.07      0.28      0.49      0.42      0.33
# max    44135.00      1.96     18.18      4.10     16.49     34.80     22.53     36.68     20.01
#
#              V9  ...       V21       V22       V23       V24       V25       V26       V27  \
# ...

# %%
class_name={0:"not fraud ",1:"fraud"}
print(data.Class.value_counts().rename(index=class_name))
# Out:
# not fraud     49461
# fraud           148
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split as tts

# %%
Y=data["Class"]
X=data.loc[:,data.columns !="Class"]
X_train,X_test,Y_train,Y_test=tts(X,Y,test_size=1/3, random_state=42, stratify=Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-a407c5cbedb5> in <cell line: 3>()
#       1 Y=data["Class"]
#       2 X=data.loc[:,data.columns !="Class"]
# ----> 3 X_train,X_test,Y_train,Y_test=tts(X,Y,test_size=1/3, random_state=42, stratify=Y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2581         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2582
# -> 2583         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2584
#    2585     return list(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    2158         to an integer.
#    2159         """
# -> 2160         y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
# ...

# %%
from sklearn.metrics import accuracy_score as As
from sklearn.linear_model import LogisticRegression

# %%
reg= LogisticRegression()

# %%
reg.fit(X_train,Y_train)
